# %% [markdown]
# ### Bibliotecas necessárias

# %%
! pip install nltk
# Out:
# Requirement already satisfied: nltk in C:\Users\55219\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.10.1)
# Requirement already satisfied: defusedxml in C:\Users\55219\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (0.7.1)
# Requirement already satisfied: click in C:\Users\55219\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (8.4.2)
# Requirement already satisfied: joblib in C:\Users\55219\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\55219\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (2025.9.18)
# Requirement already satisfied: tqdm in C:\Users\55219\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in C:\Users\55219\AppData\Local\Programs\Python\Python311\Lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# %% [markdown]
# ### Pacotes necessários

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\55219\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\55219\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# Use a variável texto a seguir para identificar as stop words
# e após isso aplique o cáculo do **TF-IDF** neste mesmo texto e observe os scores.

# %% [markdown]
# **OBS:** Para realizar essa tarefa utilize os módulos estudados na aula

# %%
texto = 'Um carro azul seguia rapidamente em uma rodovia, e ao passar por um buraco, o carro furou o pneu, e o motorista desceu do carro azul'
